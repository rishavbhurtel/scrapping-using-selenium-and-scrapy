# %%
import pandas as pd

# %%
data = pd.read_csv('comments_trustpilot_v2.csv')

# %%
data
# Out:
#                                                comment rating  \
# 0           At the moment I don't have mixed feelings.      3
# 1    Good place. Staff is nice and the prices are f...      4
# 2                 i like this and donot miss this site      5
# 3    It is a very wonderful and best service. I enj...      5
# 4                                It's cool, i love it.      5
# ..                                                 ...    ...
# 415  I have had my Kan vest for a couple of years n...      5
# 416  Knowledgeable staff informed me of the brand a...      5
# 417  Great products and customer service has been g...      5
# 418  Fantastic body protector, wouldn’t wear anythi...      5
# 419  I love my Kan, I wouldn't ride without it! Whe...      5
#
#                                            url_website       company_name  \
# 0    https://www.trustpilot.com/review/lightningsec...  Lightningsecurity
# ...
