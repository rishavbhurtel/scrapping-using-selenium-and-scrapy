# %%
import pandas as pd

# %%
data = pd.read_csv('comments_trustpilot_v2.csv')

# %%
data
# Out:
#                                               comment  rating  \
# 0                                       Excellent ...       5
# 1                  The dog become healthy. Thank you.       5
# 2                 Quality service, everyone is happy.       5
# 3   Went to Top Dog raw food this morning for the ...       5
# 4   Very stylish site, has enough information to m...       5
# ..                                                ...     ...
# 61  I love pet so much.Dogs are sometimes referred...       5
# 62      Nice.. We love pets and this is helpful to us       4
# 63  I love pet so much.Dogs are sometimes referred...       5
# 64  I love the beautiful black dog pet for breedin...       5
# 65  Here you can find your favourite bird. You can...       3
#
#                                           url_website        company_name  \
# 0      https://www.trustpilot.com/review/rentokil.com            Rentokil
# ...
